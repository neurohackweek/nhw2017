# %%
import folium
map_uw = folium.Map(location=[47.655660, -122.311805], zoom_start=16)
folium.Marker([47.65335, -122.311805], popup='eScience Institute Data Science Studio (6th floor)', icon=folium.Icon(color='blue')).add_to(map_uw)
folium.Marker([47.6565, -122.3104], popup='OUGL - Active Learning Classroom 136 (first floor)', icon=folium.Icon(color='red')).add_to(map_uw)
folium.Marker([47.655660, -122.315011], popup='Lander Hall', icon=folium.Icon(color='green')).add_to(map_uw)

# %%
map_uw
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;"></iframe></div></div>

# %%
map_uw.save('../img/map.html')
